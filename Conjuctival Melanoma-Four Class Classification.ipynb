# %% [markdown]
# Deep Learning Assignment - Conjuctival Melanoma Detection
#
# S. Anusri
# M. Bhagya Sree
# Ankith Mall
# G. Srinivas

# %%
import os
import shutil
import random
import pandas as pd 
import matplotlib.pyplot as plt
from PIL import Image, ImageOps, ImageEnhance
import numpy as np
import uuid
import torch
import glob
import torch.nn as nn
from torchvision.transforms import transforms
from torch.utils.data import DataLoader
from torch.optim import Adam
from torch.autograd import Variable
import torchvision
import pathlib

# %%
# Function to perform random rotation
def random_rotation(image, max_angle=20):
    angle = random.uniform(-max_angle, max_angle)
    return image.rotate(angle)

# Function to perform random affine transformation
def random_affine(image, translate_range=(0.05, 0.15), scaling_range=(0.9, 0.95)):
    width, height = image.size
    translate_x = random.uniform(-width*translate_range[0], width*translate_range[1])
    translate_y = random.uniform(-height*translate_range[0], height*translate_range[1])
    scaling_factor = random.uniform(scaling_range[0], scaling_range[1])
    return image.transform(image.size, Image.AFFINE, (1, 0, translate_x, 0, 1, translate_y), resample=Image.BICUBIC)

# Function to perform padding
def random_padding(image, padding_range=(0, 10), fill=(0, 0, 0), mode='constant'):
    padding = random.randint(padding_range[0], padding_range[1])
    return ImageOps.expand(image, padding, fill=fill)


# Function to perform color correction
def random_color_correction(image, brightness_range=(0, 0.2), contrast_range=(0, 0.2)):
    enhancer = ImageEnhance.Brightness(image)
    image = enhancer.enhance(1 + random.uniform(brightness_range[0], brightness_range[1]))
    enhancer = ImageEnhance.Contrast(image)
    image = enhancer.enhance(1 + random.uniform(contrast_range[0], contrast_range[1]))
    return image

# %%
# Define augmentation functions
augmentation_functions = [
    random_rotation,
    random_affine,
    random_padding,
    random_color_correction
]

# %%
def apply_augmentation(input_dir, output_dir, target_count):
    images = os.listdir(input_dir)
    current_count = len(images)
    while current_count < target_count:
        img_name = random.choice(images)
        image_path = os.path.join(input_dir, img_name)
        image = Image.open(image_path).convert("RGB")
        aug_func = random.choice(augmentation_functions)
        augmented_image = aug_func(image)
        new_img_name = f"{current_count}_a.jpg"
        augmented_image.save(os.path.join(output_dir, new_img_name))
        current_count += 1

def shuffle_and_copy_images(input_dir, output_dir, count):
    images = os.listdir(input_dir)
    random.shuffle(images)
    for i in range(count):
        img_name = images[i]
        shutil.copy(os.path.join(input_dir, img_name), os.path.join(output_dir, f"{i}.jpg"))

def split_dataset(input_dir, train_dir, val_dir, test_dir, train_ratio=0.7, val_ratio=0.1):
    images = os.listdir(input_dir)
    random.shuffle(images)
    num_images = len(images)
    num_train = int(train_ratio * num_images)
    num_val = int(val_ratio * num_images)
    train_images = images[:num_train]
    val_images = images[num_train:num_train + num_val]
    test_images = images[num_train + num_val:]
    
    # Copy images to train directory
    for img in train_images:
        shutil.copy(os.path.join(input_dir, img), os.path.join(train_dir, img))
    
    # Copy images to val directory
    for img in val_images:
        shutil.copy(os.path.join(input_dir, img), os.path.join(val_dir, img))
    
    # Copy images to test directory
    for img in test_images:
        shutil.copy(os.path.join(input_dir, img), os.path.join(test_dir, img))

source_dir = "D:\Sem 8\DL\Assignment\image_v2"
train_dir = os.path.join(source_dir, "train")
val_dir = os.path.join(source_dir, "val")
test_dir = os.path.join(source_dir, "test")

# Apply augmentation to each class individually
classes = ["normal", "nevus", "melanoma", "pterygium"]
for class_name in classes:
    class_dir = os.path.join(source_dir, class_name)
    apply_augmentation(class_dir, class_dir, 1000)  # Apply augmentation to reach 3000 images per class

# Create train, val, test directories
for directory in [train_dir, val_dir, test_dir]:
    os.makedirs(directory, exist_ok=True)

# %%
# Split dataset
for class_name in classes:
    class_dir = os.path.join(source_dir, class_name)
    train_class_dir = os.path.join(train_dir, class_name)
    val_class_dir = os.path.join(val_dir, class_name)
    test_class_dir = os.path.join(test_dir, class_name)
    os.makedirs(train_class_dir, exist_ok=True)
    os.makedirs(val_class_dir, exist_ok=True)
    os.makedirs(test_class_dir, exist_ok=True)
    split_dataset(class_dir, train_class_dir, val_class_dir, test_class_dir)

# Shuffle and copy images for each class
for class_name in classes:
    train_class_dir = os.path.join(train_dir, class_name)
    val_class_dir = os.path.join(val_dir, class_name)
    test_class_dir = os.path.join(test_dir, class_name)
    shuffle_and_copy_images(train_class_dir, train_class_dir, 700)  # 70% of 1000
    shuffle_and_copy_images(val_class_dir, val_class_dir, 100)  # 10% of 1000
    shuffle_and_copy_images(test_class_dir, test_class_dir, 200)  # 20% of 1000

print("Data augmentation and dataset splitting applied successfully!")
# Out:
# Data augmentation and dataset splitting applied successfully!

# %%
val_dir = r"D:\Sem 8\DL\Assignment\image_v2\val"

# Function to copy files from source directory to destination directory
def copy_files(source_dir, dest_dir):
    files = os.listdir(source_dir)
    for file in files:
        source_path = os.path.join(source_dir, file)
        dest_path = os.path.join(dest_dir, file)
        if os.path.isfile(dest_path):
            # If a file with the same name already exists, append a unique identifier to the filename
            file_name, file_extension = os.path.splitext(file)
            unique_id = str(uuid.uuid4())[:8]  # Generate a unique id (8 characters)
            new_file_name = f"{file_name}_{unique_id}{file_extension}"
            dest_path = os.path.join(dest_dir, new_file_name)
        shutil.move(source_path, dest_path)

# Iterate over each class folder within the val directory and copy its contents directly into val
val_classes = ["normal", "nevus", "melanoma", "pterygium"]
for val_class in val_classes:
    val_class_dir = os.path.join(val_dir, val_class)
    copy_files(val_class_dir, val_dir)

for val_class in val_classes:
    val_class_dir = os.path.join(val_dir, val_class)
    shutil.rmtree(val_class_dir)

print("Contents merged successfully!")
# Out:
# Contents merged successfully!

# %%
device=torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cpu

# %%
#Transforms
transformer=transforms.Compose([
    transforms.Resize((150, 150)),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(), #0-255 to 0-1, numpy to tensors
    transforms.Normalize([0.5, 0.5, 0.5],  #0-1 t0 [-1, 1], formula x - mean/std.dev
                        [0.5, 0.5, 0.5])
])

# %%
train_path=r'D:\Sem 8\DL\Assignment\image_v2\train'
test_path=r'D:\Sem 8\DL\Assignment\image_v2\test'


train_loader=DataLoader(
    torchvision.datasets.ImageFolder(train_path, transform=transformer),
    batch_size=256, shuffle=True
)
test_loader=DataLoader(
    torchvision.datasets.ImageFolder(test_path, transform=transformer),
    batch_size=256, shuffle=True
)

# %%
#categories
root=pathlib.Path(train_path)
classes=sorted([j.name.split('/')[-1] for j in root.iterdir()])

# %%
print(classes)
# Out:
# ['melanoma', 'nevus', 'normal', 'pterygium']

# %%
#CNN Network Class
class ConvNet(nn.Module):
    def __init__(self,num_classes=2):
        super(ConvNet,self).__init__()
        
        #Input shape=(256, 3, 150, 150) 
           #256 - Batch size, 3 RGB channels, 150 -> height, width
        #Output size after applying the convolution filter = ((w-f+2P)/s) + 1), where f = 3 (kernel size or filter size)
           #=> ((150 - 3 + 2)/1) + 1) = (149 + 1 = 150)
        self.conv1=nn.Conv2d(in_channels=3, out_channels=12, kernel_size=3, stride=1, padding=1)  #Apply the conv2d filter
        #Output shape=(256, 12, 150, 150)
        self.bn1=nn.BatchNorm2d(num_features=12)    #Batch normalization (No.of features = no.of channels), shape still remains same
        #Output shape=(256, 12, 150, 150)
        self.relu1=nn.ReLU() #Add a ReLU or Rectifier Linear Unit function
        #Output shape=(256, 12, 150, 150)
        self.pool=nn.MaxPool2d(kernel_size=2)  #Add Max Pooling layer -> reduce height and width of CNN by a factor of 2
        #Output shape=(256, 12, 75, 75)
        
        #Add one more CNN layer
        self.conv2=nn.Conv2d(in_channels=12, out_channels=20, kernel_size=3, stride=1, padding=1)  #Apply the conv2d filter
        #Output shape=(256, 20, 75, 75)
        self.relu2=nn.ReLU()
        #Output shape=(256, 20, 75, 75)
        
        
        #Add one more CNN layer
        self.conv3=nn.Conv2d(in_channels=20, out_channels=32, kernel_size=3, stride=1, padding=1)  #Apply the conv2d filter
        #Output shape=(256, 32, 75, 75)
        self.bn3=nn.BatchNorm2d(num_features=32)    #Batch normalization (No.of features = no.of channels), shape still remains same
        #Output shape=(256, 32, 75, 75)
        self.relu3=nn.ReLU()
        #Output shape=(256, 32, 75, 75)
        
        #Can add more layers to increase accuracy
        
        #Final fully connected layer:
        self.fc=nn.Linear(in_features=32*75*75, out_features=num_classes) #(32*75*75 -> depth or channels * height * width)
        
        #Feed Forward function
    def forward(self, input):
        output=self.conv1(input)
        output=self.bn1(output)
        output=self.relu1(output)
        output=self.pool(output)
            
        output=self.conv2(output)
        output=self.relu2(output)
            
        output=self.conv3(output)
        output=self.bn3(output)
        output=self.relu3(output)
            
        #Above output will be in the matrix form with shape(256, 32, 75, 75)
        output=output.view(-1, 32*75*75)
        output=self.fc(output)
        return output

# %%
model=ConvNet(num_classes=4).to(device)

# %%
#Optimizer and Loss function
optimizer=Adam(model.parameters(), lr=0.001, weight_decay=0.0001)
loss_function=nn.CrossEntropyLoss()

# %%
num_epochs=3 #Hyperparameter that can be tuned

# %%
#Calculate the size of train and test images
train_count=len(glob.glob(train_path+'/**/*.jpg'))
test_count=len(glob.glob(test_path+'/**/*.jpg'))

# %%
print(f"The value of train_count is: {train_count} and the value of test_count is: {test_count}")
# Out:
# The value of train_count is: 5327 and the value of test_count is: 1515

# %%
#Model training and save the best model
best_accuracy=0.0
for epoch in range(num_epochs):
    #Evaluation and training on the training dataset
    model.train()
    train_accuracy=0.0
    train_loss=0.0
    for i,(images, labels) in enumerate(train_loader):
        if torch.cuda.is_available():
            images=Variable(images.cuda())
            labels=Variable(labels.cuda())
        optimizer.zero_grad()   #To avoid mixing up of gradients between the batches, zero them out at the start of a new batch
        outputs=model(images)   #Gives the prediction
        loss=loss_function(outputs, labels)  #Computation of loss based on predicted and actual value
        loss.backward() #Back propagation
        optimizer.step() #Updates the weight and bias
        
        train_loss+=loss.cpu().data*images.size(0)
        _,prediction=torch.max(outputs.data, 1)
        
        train_accuracy+=int(torch.sum(prediction==labels.data))
    train_accuracy/=train_count
    train_loss/=train_count
    
    #Evaluation on testing dataset
    model.eval()
    
    test_accuracy=0.0
    for i, (images, labels) in enumerate(test_loader):
        if torch.cuda.is_available():
            images=Variable(images.cuda())
            labels=Variable(labels.cuda())
        outputs=model(images)
        _,prediction=torch.max(outputs.data, 1)
        test_accuracy+=int(torch.sum(prediction==labels.data))
        
    test_accuracy/=test_count
    print('Epoch: '+str(epoch)+' Train Loss: '+str(train_loss)+' Train Accuracy: '+str(train_accuracy)+' Test Accuracy: '+str(test_accuracy))
    #Save the best model:
    if test_accuracy > best_accuracy:
        torch.save(model.state_dict(), 'best_checkpoint.model')
        best_accuracy=test_accuracy
# Out:
# Epoch: 0 Train Loss: tensor(11.6932) Train Accuracy: 0.49615168012014266 Test Accuracy: 0.5828382838283829
# Epoch: 1 Train Loss: tensor(2.0325) Train Accuracy: 0.7766097240473062 Test Accuracy: 0.6917491749174918
# Epoch: 2 Train Loss: tensor(0.5592) Train Accuracy: 0.9074525999624554 Test Accuracy: 0.866006600660066

# %%
train_path=r'D:\Sem 8\DL\Assignment\image_v2\train'
test_path=r'D:\Sem 8\DL\Assignment\image_v2\test'

# %%
#categories
root=pathlib.Path(train_path)
classes=sorted([j.name.split('/')[-1] for j in root.iterdir()])
print(classes)
# Out:
# ['melanoma', 'nevus', 'normal', 'pterygium']

# %%
#CNN Network Class
class ConvNet(nn.Module):
    def __init__(self,num_classes=4):
        super(ConvNet,self).__init__()
        
        #Input shape=(256, 3, 150, 150) 
           #256 - Batch size, 3 RGB channels, 150 -> height, width
        #Output size after applying the convolution filter = ((w-f+2P)/s) + 1), where f = 3 (kernel size or filter size)
           #=> ((150 - 3 + 2)/1) + 1) = (149 + 1 = 150)
        self.conv1=nn.Conv2d(in_channels=3, out_channels=12, kernel_size=3, stride=1, padding=1)  #Apply the conv2d filter
        #Output shape=(256, 12, 150, 150)
        self.bn1=nn.BatchNorm2d(num_features=12)    #Batch normalization (No.of features = no.of channels), shape still remains same
        #Output shape=(256, 12, 150, 150)
        self.relu1=nn.ReLU() #Add a ReLU or Rectifier Linear Unit function
        #Output shape=(256, 12, 150, 150)
        self.pool=nn.MaxPool2d(kernel_size=2)  #Add Max Pooling layer -> reduce height and width of CNN by a factor of 2
        #Output shape=(256, 12, 75, 75)
        
        #Add one more CNN layer
        self.conv2=nn.Conv2d(in_channels=12, out_channels=20, kernel_size=3, stride=1, padding=1)  #Apply the conv2d filter
        #Output shape=(256, 20, 75, 75)
        self.relu2=nn.ReLU()
        #Output shape=(256, 20, 75, 75)
        
        
        #Add one more CNN layer
        self.conv3=nn.Conv2d(in_channels=20, out_channels=32, kernel_size=3, stride=1, padding=1)  #Apply the conv2d filter
        #Output shape=(256, 32, 75, 75)
        self.bn3=nn.BatchNorm2d(num_features=32)    #Batch normalization (No.of features = no.of channels), shape still remains same
        #Output shape=(256, 32, 75, 75)
        self.relu3=nn.ReLU()
        #Output shape=(256, 32, 75, 75)
        
        #Can add more layers to increase accuracy
        
        #Final fully connected layer:
        self.fc=nn.Linear(in_features=32*75*75, out_features=num_classes) #(32*75*75 -> depth or channels * height * width)
        
        #Feed Forward function
    def forward(self, input):
        output=self.conv1(input)
        output=self.bn1(output)
        output=self.relu1(output)
        output=self.pool(output)
            
        output=self.conv2(output)
        output=self.relu2(output)
            
        output=self.conv3(output)
        output=self.bn3(output)
        output=self.relu3(output)
            
        #Above output will be in the matrix form with shape(256, 32, 75, 75)
        output=output.view(-1, 32*75*75)
        output=self.fc(output)
        return output

# %%
checkpoint=torch.load('best_checkpoint.model')
model=ConvNet(num_classes=4)
model.load_state_dict(checkpoint)
model.eval()
# Out:
# ConvNet(
#   (conv1): Conv2d(3, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn1): BatchNorm2d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu1): ReLU()
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(12, 20, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (relu2): ReLU()
#   (conv3): Conv2d(20, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu3): ReLU()
#   (fc): Linear(in_features=180000, out_features=4, bias=True)
# )

# %%
#Transforms
transformer=transforms.Compose([
    transforms.Resize((150, 150)),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(), #0-255 to 0-1, numpy to tensors
    transforms.Normalize([0.5, 0.5, 0.5],  #0-1 t0 [-1, 1], formula x - mean/std.dev
                        [0.5, 0.5, 0.5])
])

# %%
def prediction(img_path, transformer):
    image = Image.open(img_path)
    
    if image.mode != 'RGB':
        image = image.convert('RGB')
    
    image_tensor = transformer(image).float()
    image_tensor = image_tensor.unsqueeze_(0)
    input = Variable(image_tensor)
    model.eval()  # Set the model to evaluation mode
    output = model(input)
    index = output.data.numpy().argmax()
    pred = classes[index]
    return pred

# %%
val_path=r'D:\Sem 8\DL\Assignment\image_v2\val'
images_path=glob.glob(val_path+'/*.jpg')

# %%
images_path
# Out:
# ['D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\0.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\0_beabd9f3.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\0_d1f3d7f0.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\0_d51bdba6.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\1.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\10.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\100_a.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\102_a.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\104_a.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\108_a.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\109_a.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\10_0363fbc7.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\10_30c5ea98.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\10_9413573b.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\11.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\115_a.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\116_a.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\11_83363a2a.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\11_fb781aa3.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\11_fcf54abc.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\12.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\122_a.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\123_a.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\128_a.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\12_0018d573.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\12_d4f79d09.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\12_ec72f2a9.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\13.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\133_a.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\136_a.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\138_a.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\13_6075a1fc.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\13_6cb56144.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\13_f786a451.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\14.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\142_a.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\145_a.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\146_a.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\148_a.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\149_a.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\149_a_317aa396.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\14_8b9de3c6.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\14_b1dec888.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\14_e1654330.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\15.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\154_a.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\156_a.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\15_4fafbaa6.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\15_f48ff9b5.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\15_fdba6fff.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\16.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\160_a.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\160_a_62c203d5.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\162_a.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\163_a.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\164_a.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\169_a.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\169_a_d1ef4c5b.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\16_a878f4c5.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\16_dc5269ff.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\16_e07740ff.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\17.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\170_a.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\173_a.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\175_a.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\177_a.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\177_a_a79ab2e3.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\178_a.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\179_a.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\17_7fe5d13a.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\17_9bf4a640.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\17_9d3d0a0f.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\18.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\180_a.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\182_a.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\185_a.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\185_a_ff68b264.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\187_a.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\189_a.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\18_3d4f00af.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\18_62218550.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\18_89c661b4.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\19.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\193_a.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\19_06beeb75.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\19_d82c3a00.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\19_e3329990.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\1_50b36c7a.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\1_ec7d1940.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\1_fcd5b338.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\2.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\20.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\203_a.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\205_a.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\206_a.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\207_a.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\208_a.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\20_1833c3c2.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\20_af4e185c.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\20_b4b45ce2.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\21.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\210_a.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\212_a.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\213_a.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\217_a.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\21_380e6f14.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\21_3cf3238b.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\21_b4c88e00.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\22.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\221_a.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\223_a.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\226_a.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\227_a.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\22_353ce286.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\22_c6326be5.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\22_e3b956a5.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\23.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\230_a.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\235_a.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\236_a.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\237_a.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\23_1d865553.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\23_4db5ef6d.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\23_dad8f747.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\24.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\240_a.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\241_a.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\242_a.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\244_a.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\247_a.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\248_a.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\249_a.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\24_6cbb2a7b.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\24_8915df17.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\24_b1af6af5.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\25.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\250_a.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\251_a.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\252_a.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\253_a.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\255_a.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\25_00983e2f.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\25_3575a498.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\25_fee914f4.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\26.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\262_a.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\264_a.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\26_10a7b62b.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\26_a97202c4.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\26_bbfd6036.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\27.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\270_a.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\273_a.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\273_a_2ec739da.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\275_a.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\276_a.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\278_a.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\27_44f4b291.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\27_8124b8fe.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\27_f5a440f5.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\28.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\282_a.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\289_a.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\\28_85511899.jpg',
#  'D:\\Sem 8\\DL\\Assignment\\image_v2\\val\